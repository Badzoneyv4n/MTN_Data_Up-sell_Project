# %% [markdown]
# # 📊 Model Comparison Summary
#
# I trained and compared two classification models — Random Forest as a baseline model and XGBoost — to predict which new smartphone users will to increase their data usage after an upgrade. The goal was to identify high-potential users for targeted upsell campaigns.
#
# # ✅ 1. Random Forest (Baseline Model)
#
# - Test Precision: 1.0000
#
# - Test AUC-ROC: 0.8750
#
# - Train AUC-ROC: 1.0000
#
# **Top Features Used:**
#
# - avg_data_before_upgrade (56%)
#
# - std_before (17%)
#
# - total_recharge_before (14%)
#
# Others (low influence: data_flag, recharge_flag, std_flag)
#
# **🧠 Insight:**
#
# The Random Forest model provided strong performance with perfect precision and good AUC. It used multiple features and showed a relatively balanced reliance across them.
#
# # ✅ 2. XGBoost (Final Model)
#
# - Test Precision: 1.0000
#
# - Test AUC-ROC: 0.9688 🥇
#
# - Train AUC-ROC: 1.0000
#
# **Top Features Used:**
#
# - avg_data_before_upgrade (96%) 💪
#
# - total_recharge_before (4%)
#
# - All other features were unused (0%)
#
# **🧠 Insight:**
#
# The XGBoost model outperformed the baseline in terms of AUC-ROC, indicating a stronger ability to rank users by growth potential. It relied almost entirely on just two key features, making it highly efficient and easy to interpret.
#
# # 📈 Conclusion
#
# Metric	Random Forest	XGBoost (Final)
#
# Precision	1.0000	1.0000
#
# AUC (Test)	0.8750	0.9688 ✅
#
# Train AUC	1.0000	1.0000
#
# Top Feature	avg_data_before (56%)	avg_data_before (96%)
#
# ✅ Based on AUC-ROC and simplicity, XGBoost was selected as the final model for scoring users in the data upsell campaign.
