# %% [markdown]
# Check the modeling notebook for **predictions**

# %% [markdown]
# # Load the xgb scored new data set

# %%
import pandas as pd

import sys
import os

# Add the parent directory's 'scripts' folder to the Python path
sys.path.append(os.path.abspath('../scripts'))

from campaigns import campaigns

df = pd.read_csv('../data/cleaned/users_segmented_xgb_score.csv')
df.head()
# Out:
#            user  avg_data_before_upgrade  std_before  total_recharge_before  \
# 0  225798765432                 0.130697    0.452746            3091.482637
# 1  225798765433                      NaN         NaN                    NaN
# 2  225798765434                      NaN         NaN                    NaN
# 3  225798765435                 0.261393    0.452746             450.000000
# 4  225798765436                 7.143986   32.579923           13800.000000
#
#    avg_data_after_upgrade      std_after  total_recharge_after  \
# 0           282355.658691  746850.094482          10600.000000
# 1           390674.369565  760990.974794          15979.550000
# 2            77583.160156  109719.157305            275.000000
# 3           156755.774613  284752.858237          25581.482637
# 4            42745.234739  113248.911365          32883.892637
#
#    days_active_after  time_to_first_data_use  recharge_growth  \
# 0                 14                       0      7508.517363
# 1                 10                       0              NaN
# 2                  1                       0              NaN
# 3                 26                       0     25131.482637
# 4                 23                       0     19083.892637
#
#    increased_usage user_segment  xgb_score  xgb_pred
# 0                1         high   0.032779         0
# 1                0         high   0.027751         0
# 2                0          low   0.027751         0
# 3                1       medium   0.032779         0
# 4                1          low   0.888021         1

# %%
# Out:
#            user  avg_data_before_upgrade  std_before  total_recharge_before  \
# 0  225798765432                 0.130697    0.452746            3091.482637
# 1  225798765433                      NaN         NaN                    NaN
# 2  225798765434                      NaN         NaN                    NaN
# 3  225798765435                 0.261393    0.452746             450.000000
# 4  225798765436                 7.143986   32.579923           13800.000000
#
#    avg_data_after_upgrade      std_after  total_recharge_after  \
# 0           282355.658691  746850.094482          10600.000000
# 1           390674.369565  760990.974794          15979.550000
# 2            77583.160156  109719.157305            275.000000
# 3           156755.774613  284752.858237          25581.482637
# 4            42745.234739  113248.911365          32883.892637
#
#    days_active_after  time_to_first_data_use  recharge_growth  \
# 0                 14                       0      7508.517363
# 1                 10                       0              NaN
# 2                  1                       0              NaN
# 3                 26                       0     25131.482637
# 4                 23                       0     19083.892637
#
#    increased_usage user_segment
# 0                1         high
# 1                0         high
# 2                0          low
# 3                1       medium
# 4                1          low

# %% [markdown]
# # Generate the campaign target list.

# %% [markdown]
# Sort Users by Score and Flag Top 20%

# %%
df_sorted = df.sort_values(by='xgb_score', ascending=False)
top_20_count = int(len(df_sorted) * 0.2)
df_sorted['upsell_target'] = 0
df_sorted.iloc[:top_20_count, df_sorted.columns.get_loc('upsell_target')] = 1

# %% [markdown]
# Suggest campaigns for each user

# %%
df_sorted['suggested_Campaign'] = df_sorted.apply(campaigns, axis=1)

# %% [markdown]
# save the new dataframe of data upsell targets

# %%
df_sorted.to_csv('../data/cleaned/data_upsell_targets.csv', index=False)
